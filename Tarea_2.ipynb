# %% [markdown]
# # Problema A, modelo AR

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X1=numeric(100)

# %%
# AR(1).1: X(t)=Z(t)+0.8X(t−1)
phis=c(1, 0.8) #Parametros phis
for(i in aux) {
X1[i]=t(phis)%*%c(zt[i],X1[i-1])
}
AR1.1=ts(X1, start=1, frequency=1)
plot(AR1.1, main='AR(1).1: X(t)=Z(t)+0.8X(t−1)')
acf(AR1.1)
pacf(AR1.1)
# Out:
# Plot with title “AR(1).1: X(t)=Z(t)+0.8X(t−1)”
# Plot with title “Series  AR1.1”
# Plot with title “Series  AR1.1”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X1=numeric(100)

# %%
# AR(1).2: X(t)=Z(t)-0.7X(t−1)
phis=c(1, -0.7) #Parametros phis
for(i in aux) {
X1[i]=t(phis)%*%c(zt[i],X1[i-1])
}
AR1.2=ts(X1, start=1, frequency=1)
plot(AR1.2, main='AR(1).2: X(t)=Z(t)-0.7X(t−1)')
acf(AR1.2)
pacf(AR1.2)
# Out:
# Plot with title “AR(1).2: X(t)=Z(t)-0.7X(t−1)”
# Plot with title “Series  AR1.2”
# Plot with title “Series  AR1.2”

# %%
zt=rnorm (100, 0, 1)
m=2 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X2=numeric(100)

# %%
# AR(2).1: X(t)=Z(t)+0.3X(t−1)-0.2X(t-2)
phis=c(1,0.3,-0.2) #Parametros phis
for(i in aux) {
X2[i]=t(phis)%*%c(zt[i],X2[i-1],X2[i-2])
}
AR2.1=ts(X2, start=1, frequency=1)
plot(AR2.1, main='AR(2).1: X(t)=Z(t)+0.3X(t−1)-0.2X(t-2)')
acf(AR2.1)
pacf(AR2.1)
# Out:
# Plot with title “AR(2).1: X(t)=Z(t)+0.3X(t−1)-0.2X(t-2)”
# Plot with title “Series  AR2.1”
# Plot with title “Series  AR2.1”

# %%
zt=rnorm (100, 0, 1)
m=2 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X2=numeric(100)

# %%
# AR(2).2: X(t)=Z(t)+0.3X(t−1)+0.6X(t-2)
phis=c(1,0.3,0.6) #Parametros phis
for(i in aux) {
X2[i]=t(phis)%*%c(zt[i],X2[i-1],X2[i-2])
}
AR2.2=ts(X2, start=1, frequency=1)
plot(AR2.2, main='AR(2).2: X(t)=Z(t)+0.3X(t−1)+0.6X(t-2)')
acf(AR2.2)
pacf(AR2.2)
# Out:
# Plot with title “AR(2).2: X(t)=Z(t)+0.3X(t−1)+0.6X(t-2)”
# Plot with title “Series  AR2.2”
# Plot with title “Series  AR2.2”

# %%
zt=rnorm (100, 0, 1)
m=3 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X3=numeric(100)

# %%
# AR(3).1: X(t)=Z(t)+0.8X(t−1)+0.25X(t-2)-0.2X(t-3)
phis=c(1,0.8,0.25,-0.2) #Parametros phis
for(i in aux) {
X3[i]=t(phis)%*%c(zt[i],X3[i-1],X3[i-2],X3[i-3])
}
AR3.1=ts(X3, start=1, frequency=1)
plot(AR3.1, main='AR(3).1: X(t)=Z(t)+0.8X(t−1)+0.25X(t-2)-0.2X(t-3)')
acf(AR3.1)
pacf(AR3.1)
# Out:
# Plot with title “AR(3).1: X(t)=Z(t)+0.8X(t−1)+0.25X(t-2)-0.2X(t-3)”
# Plot with title “Series  AR3.1”
# Plot with title “Series  AR3.1”

# %%
zt=rnorm (100, 0, 1)
m=3 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(m+1):100
X3=numeric(100)

# %%
# AR(3).2: X(t)=Z(t)+0.2X(t−1)+0.25X(t-2)-0.05X(t-3)
phis=c(1,0.2,0.25,-0.05) #Parametros phis
for(i in aux) {
X3[i]=t(phis)%*%c(zt[i],X3[i-1],X3[i-2],X3[i-3])
}
AR3.2=ts(X3, start=1, frequency=1)
plot(AR3.2, main='AR(3).2: X(t)=Z(t)+0.2X(t−1)+0.25X(t-2)-0.05X(t-3)')
acf(AR3.2)
pacf(AR3.2)
# Out:
# Plot with title “AR(3).2: X(t)=Z(t)+0.2X(t−1)+0.25X(t-2)-0.05X(t-3)”
# Plot with title “Series  AR3.2”
# Plot with title “Series  AR3.2”

# %% [markdown]
# # Problema B, modelos MA

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(n+1):100
X1=numeric(100)

# %%
# MA(1).1: X(t)=Z(t)+0.8Z(t-1)
thetas=c(1,0.8) #Parametros thetas
for(i in aux) {
X1[i]=t(thetas)%*%c(zt[i],zt[i-1])
}
MA1.1=ts(X1, start=1, frequency=1)
plot(MA1.1, main='MA(1).1: X(t)=Z(t)+0.8Z(t-1)')
acf(MA1.1)
pacf(MA1.1)
# Out:
# Plot with title “MA(1).1: X(t)=Z(t)+0.8Z(t-1)”
# Plot with title “Series  MA1.1”
# Plot with title “Series  MA1.1”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=1 #Numero de parametros para theta
aux<-(n+1):100
X1=numeric(100)

# %%
# MA(1).2: X(t)=Z(t)-0.7Z(t-1)
thetas=c(1,-0.7) #Parametros thetas
for(i in aux) {
X1[i]=t(thetas)%*%c(zt[i],zt[i-1])
}
MA1.2=ts(X1, start=1, frequency=1)
plot(MA1.2, main='MA(1).2: X(t)=Z(t)-0.7Z(t-1)')
acf(MA1.2)
pacf(MA1.2)
# Out:
# Plot with title “MA(1).2: X(t)=Z(t)-0.7Z(t-1)”
# Plot with title “Series  MA1.2”
# Plot with title “Series  MA1.2”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=2 #Numero de parametros para theta
aux<-(n+1):100
X2=numeric(100)

# %%
# MA(2).1: X(t)=Z(t)-0.5Z(t-1)+0.3Z(t-2)
thetas=c(1,-0.5,0.3) #Parametros thetas
for(i in aux) {
X2[i]=t(thetas)%*%c(zt[i],zt[i-1],zt[i-2])
}
MA2.1=ts(X2, start=1, frequency=1)
plot(MA2.1, main='MA(2).1: X(t)=Z(t)-0.5Z(t-1)+0.3Z(t-2)')
acf(MA2.1)
pacf(MA2.1)
# Out:
# Plot with title “MA(2).1: X(t)=Z(t)-0.5Z(t-1)+0.3Z(t-2)”
# Plot with title “Series  MA2.1”
# Plot with title “Series  MA2.1”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=2 #Numero de parametros para theta
aux<-(n+1):100
X2=numeric(100)

# %%
# MA(2).2: X(t)=Z(t)-0.3Z(t-1)+0.8Z(t-2)
thetas=c(1,-0.3,0.8) #Parametros thetas
for(i in aux) {
X2[i]=t(thetas)%*%c(zt[i],zt[i-1],zt[i-2])
}
MA2.2=ts(X2, start=1, frequency=1)
plot(MA2.2, main='MA(2).2: X(t)=Z(t)-0.3Z(t-1)+0.8Z(t-2)')
acf(MA2.2)
pacf(MA2.2)
# Out:
# Plot with title “MA(2).2: X(t)=Z(t)-0.3Z(t-1)+0.8Z(t-2)”
# Plot with title “Series  MA2.2”
# Plot with title “Series  MA2.2”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=3 #Numero de parametros para theta
aux<-(n+1):100
X2=numeric(100)

# %%
# MA(3).1: X(t)=Z(t)-0.4Z(t-1)+5Z(t-2)-0.2Z(t-3)
thetas=c(1,-0.4,5,-0.2) #Parametros thetas
for(i in aux) {
X3[i]=t(thetas)%*%c(zt[i],zt[i-1],zt[i-2],zt[i-3])
}
MA3.1=ts(X3, start=1, frequency=1)
plot(MA3.1, main='MA(3).1: X(t)=Z(t)-0.4Z(t-1)+5Z(t-2)-0.2Z(t-3)')
acf(MA3.1)
pacf(MA3.1)
# Out:
# Plot with title “MA(3).1: X(t)=Z(t)-0.4Z(t-1)+5Z(t-2)-0.2Z(t-3)”
# Plot with title “Series  MA3.1”
# Plot with title “Series  MA3.1”

# %%
zt=rnorm (100, 0, 1)
m=1 #Numero de parametros para phi
n=3 #Numero de parametros para theta
aux<-(n+1):100
X2=numeric(100)

# %%
# MA(3).2: X(t)=Z(t)+2Z(t-1)+3.5Z(t-2)-1.2Z(t-3)
thetas=c(1,2,3.5,-1.2) #Parametros thetas
for(i in aux) {
X3[i]=t(thetas)%*%c(zt[i],zt[i-1],zt[i-2],zt[i-3])
}
MA3.2=ts(X3, start=1, frequency=1)
plot(MA3.2, main='MA(3).2: X(t)=Z(t)+2Z(t-1)+3.5Z(t-2)-1.2Z(t-3)')
acf(MA3.2)
pacf(MA3.2)
# Out:
# Plot with title “MA(3).2: X(t)=Z(t)+2Z(t-1)+3.5Z(t-2)-1.2Z(t-3)”
# Plot with title “Series  MA3.2”
# Plot with title “Series  MA3.2”

# %% [markdown]
# # Problema C, modelos ARMA

# %%
ARMA11.1 <- arima.sim(model=list( ar=c(0.8), ma=c(0.8)), n = 100)

plot(ARMA11.1 , main='Modelo Arma con parametros p=1, q=1, simulación 1')
acf(ARMA11.1 )
pacf(ARMA11.1 )
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=1, simulación 1”
# Plot with title “Series  ARMA11.1”
# Plot with title “Series  ARMA11.1”

# %%
ARMA11.2 <- arima.sim(model=list( ar=c(-0.7), ma=c(-0.7)), n = 100)

plot(ARMA11.2  , main='Modelo Arma con parametros p=1, q=1, simulación 2')
acf(ARMA11.2)
pacf(ARMA11.2)
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=1, simulación 2”
# Plot with title “Series  ARMA11.2”
# Plot with title “Series  ARMA11.2”

# %%
ARMA21.1 <- arima.sim(model=list( ar=c(0.3,-0.2), ma=c(0.8)), n = 100)

plot(ARMA21.1  , main='Modelo Arma con parametros p=2, q=1, simulación 1')
acf(ARMA21.1)
pacf(ARMA21.1)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=1, simulación 1”
# Plot with title “Series  ARMA21.1”
# Plot with title “Series  ARMA21.1”

# %%
ARMA21.2 <- arima.sim(model=list( ar=c(0.3,0.6), ma=c(-0.7)), n = 100)

plot(ARMA21.2  , main='Modelo Arma con parametros p=2, q=1, simulación 2')
acf(ARMA21.2)
pacf(ARMA21.2)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=1, simulación 2”
# Plot with title “Series  ARMA21.2”
# Plot with title “Series  ARMA21.2”

# %%
ARMA31.1 <- arima.sim(model=list( ar=c(0.8,0.25,-0.2), ma=c(0.8)), n = 100)

plot(ARMA31.1  , main='Modelo Arma con parametros p=3, q=1, simulación 1')
acf(ARMA31.1)
pacf(ARMA31.1)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=1, simulación 1”
# Plot with title “Series  ARMA31.1”
# Plot with title “Series  ARMA31.1”

# %%
ARMA31.2 <- arima.sim(model=list( ar=c(0.2,0.25,-0.05), ma=c(-0.7)), n = 100)

plot(ARMA31.2  , main='Modelo Arma con parametros p=3, q=1, simulación 2')
acf(ARMA31.2)
pacf(ARMA31.2)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=1, simulación 2”
# Plot with title “Series  ARMA31.2”
# Plot with title “Series  ARMA31.2”

# %%
ARMA12.1 <- arima.sim(model=list( ar=c(0.8), ma=c(-0.5,0.3)), n = 100)

plot(ARMA12.1  , main='Modelo Arma con parametros p=1, q=2, simulación 1')
acf(ARMA12.1)
pacf(ARMA12.1)
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=2, simulación 1”
# Plot with title “Series  ARMA12.1”
# Plot with title “Series  ARMA12.1”

# %%
ARMA12.2 <- arima.sim(model=list( ar=c(-0.7), ma=c(-0.3,0.8)), n = 100)

plot(ARMA12.2  , main='Modelo Arma con parametros p=1, q=2, simulación 2')
acf(ARMA12.2)
pacf(ARMA12.2)
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=2, simulación 2”
# Plot with title “Series  ARMA12.2”
# Plot with title “Series  ARMA12.2”

# %%
ARMA22.1 <- arima.sim(model=list( ar=c(0.3,-0.2), ma=c(-0.5,0.3)), n = 100)

plot(ARMA22.1 , main='Modelo Arma con parametros p=2, q=2, simulación 1')
acf(ARMA22.1)
pacf(ARMA22.1)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=2, simulación 1”
# Plot with title “Series  ARMA22.1”
# Plot with title “Series  ARMA22.1”

# %%
ARMA22.2 <- arima.sim(model=list( ar=c(0.3,0.6), ma=c(-0.3,0.8)), n = 100)

plot(ARMA22.2  , main='Modelo Arma con parametros p=2, q=2, simulación 2')
acf(ARMA22.2)
pacf(ARMA22.2)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=2, simulación 2”
# Plot with title “Series  ARMA22.2”
# Plot with title “Series  ARMA22.2”

# %%
ARMA32.1 <- arima.sim(model=list( ar=c(0.8,0.25,-0.2), ma=c(-0.5,0.3)), n = 100)

plot(ARMA32.1 , main='Modelo Arma con parametros p=3, q=2, simulación 1')
acf(ARMA32.1)
pacf(ARMA32.1)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=2, simulación 1”
# Plot with title “Series  ARMA32.1”
# Plot with title “Series  ARMA32.1”

# %%
ARMA32.2 <- arima.sim(model=list( ar=c(0.2,0.25,-0.05), ma=c(-0.3,0.8)), n = 100)

plot(ARMA32.2 , main='Modelo Arma con parametros p=3, q=2, simulación 2')
acf(ARMA32.2)
pacf(ARMA32.2)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=2, simulación 2”
# Plot with title “Series  ARMA32.2”
# Plot with title “Series  ARMA32.2”

# %%
ARMA13.1 <- arima.sim(model=list( ar=c(0.8), ma=c(-0.4,5,-0.2)), n = 100)

plot(ARMA13.1, main='Modelo Arma con parametros p=1, q=3, simulación 1')
acf(ARMA13.1)
pacf(ARMA13.1)
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=3, simulación 1”
# Plot with title “Series  ARMA13.1”
# Plot with title “Series  ARMA13.1”

# %%
ARMA13.2 <- arima.sim(model=list( ar=c(-0.7), ma=c(2,3.5,-1.2)), n = 100)

plot(ARMA13.2 , main='Modelo Arma con parametros p=1, q=3, simulación 2')
acf(ARMA13.2)
pacf(ARMA13.2)
# Out:
# Plot with title “Modelo Arma con parametros p=1, q=3, simulación 2”
# Plot with title “Series  ARMA13.2”
# Plot with title “Series  ARMA13.2”

# %%
ARMA23.1 <- arima.sim(model=list( ar=c(0.3,-0.2), ma=c(-0.4,5,-0.2)), n = 100)

plot(ARMA23.1 , main='Modelo Arma con parametros p=2, q=3, simulación 1')
acf(ARMA23.1)
pacf(ARMA23.1)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=3, simulación 1”
# Plot with title “Series  ARMA23.1”
# Plot with title “Series  ARMA23.1”

# %%
ARMA23.2 <- arima.sim(model=list( ar=c(0.3,0.6), ma=c(2,3.5,-1.2)), n = 100)

plot(ARMA23.2 , main='Modelo Arma con parametros p=2, q=3, simulación 2')
acf(ARMA23.2)
pacf(ARMA23.2)
# Out:
# Plot with title “Modelo Arma con parametros p=2, q=3, simulación 2”
# Plot with title “Series  ARMA23.2”
# Plot with title “Series  ARMA23.2”

# %%
ARMA33.1 <- arima.sim(model=list( ar=c(0.8,0.25,-0.2), ma=c(-0.4,5,-0.2)), n = 100)

plot(ARMA33.1 , main='Modelo Arma con parametros p=3, q=3, simulación 1')
acf(ARMA33.1)
pacf(ARMA33.1)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=3, simulación 1”
# Plot with title “Series  ARMA33.1”
# Plot with title “Series  ARMA33.1”

# %%
ARMA33.2 <- arima.sim(model=list( ar=c(0.2,0.25,-0.05), ma=c(2,3.5,-1.2)), n = 100)

plot(ARMA33.2 , main='Modelo Arma con parametros p=3, q=3, simulación 2')
acf(ARMA33.2)
pacf(ARMA33.2)
# Out:
# Plot with title “Modelo Arma con parametros p=3, q=3, simulación 2”
# Plot with title “Series  ARMA33.2”
# Plot with title “Series  ARMA33.2”
